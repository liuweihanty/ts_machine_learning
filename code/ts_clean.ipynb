# %% [markdown]
# # Cleaning & Manipulation of Chr7 Genes Score Data

# %%
#Author: Shirley Zhou

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ts_master_list = pd.read_csv("../data/Chr7_master_list.csv")
ts_master_list.head(3)
# Out:
#    Unnamed: 0      Gene       ENSEMBL_ID  Brummelkamp.hap1.GTS.ratio  \
# 0         776  VKORC1L1  ENSG00000196715                        0.46
# 1         390     KCTD7  ENSG00000243335                        0.55
# 2         420    LRRC17  ENSG00000128606                         NaN
#
#    Brummelkamp.hap1.GTS.threshold  Brummelkamp.kbm7.GTS.ratio  \
# 0                               0                    0.531993
# 1                               0                    0.542857
# 2                               0                         NaN
#
#    Brummelkamp.kbm7.GTS.threshold  Campbell2018.LAML.pvalues  \
# 0                               0                        NaN
# 1                               0                        NaN
# 2                               0                        NaN
#
#    Campbell2018.PANCANCER.pvalues  Campbell2018.Combined.pvalues  ...  \
# 0                             NaN                            NaN  ...
# 1                             NaN                            NaN  ...
# 2                             NaN                            NaN  ...
#
#    Sabbatini2017.THP.1  Sabbatini2017.THP.1.threshold  \
# 0               -0.031                              0
# 1               -0.424                              0
# 2               -0.130                              0
#
#    Wallace2016.DEseq2.Log2.Fold.Change  Wallace2016.DEseq2.P.Value  \
# 0                             1.440088                    0.000159
# 1                             1.087654                    0.011067
# 2                                  NaN                         NaN
#
#    Wallace2016.threshold  Weissman2016a.Rep1_2.Mann.Whitney.p.value  \
# 0                      1                                   0.000412
# 1                      1                                   0.003739
# 2                      0                                   0.013048
#
#    Weissman2016a.average.phenotype.of.strongest.3.2  Weissman2016a.threshold  \
# 0                                         -0.034013                        1
# 1                                         -0.027808                        1
# 2                                         -0.030304                        1
#
#    Weissman2016i.Rep1_2.Mann.Whitney.p.value  \
# 0                                   0.054796
# 1                                   0.704017
# 2                                   0.181169
#
#    Weissman2016i.average.phenotype.of.strongest.3.2
# 0                                          0.014270
# 1                                          0.013199
# 2                                         -0.021738
#
# [3 rows x 83 columns]

# %%
ts_score = pd.read_csv("../data/Rank_variables_master_list.csv")
ts_score.head(3)
# Out:
#     Gene  Entrez.GeneID       ENSEMBL_ID  Brummelkamp.hap1.GTS.ratio  \
# 0  POLD2         5425.0  ENSG00000106628                    0.246339
# 1   EZH2         2146.0  ENSG00000106462                    0.414478
# 2  PTCD1        26024.0  ENSG00000106246                    0.486842
#
#    Brummelkamp.hap1.GTS.threshold  Brummelkamp.kbm7.GTS.ratio  \
# 0                               0                    0.207792
# 1                               0                    0.211823
# 2                               0                    0.488024
#
#    Brummelkamp.kbm7.GTS.threshold  Campbell2018.LAML.pvalues  \
# 0                               0                        NaN
# 1                               0                     0.0498
# 2                               0                        NaN
#
#    Campbell2018.PANCANCER.pvalues  Campbell2018.Combined.pvalues  ...  \
# 0                             NaN                            NaN  ...
# 1                             1.0                       0.065506  ...
# 2                             NaN                            NaN  ...
#
#    Sabbatini2017.THP.1  Sabbatini2017.THP.1.threshold  \
# 0               -3.567                              0
# 1               -1.605                              0
# 2               -1.544                              0
#
#    Wallace2016.DEseq2.Log2.Fold.Change  Wallace2016.DEseq2.P.Value  \
# 0                             1.130542                    0.024891
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
#
#    Wallace2016.threshold  \
# 0                      1
# 1                      0
# 2                      0
#
#    Weissman2016a.mean.Replicate1_n_2.Mann.Whitney.p.value  \
# 0                                           0.137059
# 1                                           0.798109
# 2                                           0.186927
#
#    Weissman2016a.CS.average.phenotype.of.strongest.3.2  \
# 0                                          -0.012419
# 1                                          -0.000228
# 2                                          -0.016081
#
#    Weissman2016a.threshold  Weissman2016i.Rep1_2.Mann.Whitney.p.value  \
# 0                        0                                   0.000007
# 1                        0                                   0.021934
# 2                        0                                   0.000299
#
#    Weissman2016i.average.phenotype.of.strongest.3 guides.comb(avg CS for replicate 1 and 2)
# 0                                          -0.205830
# 1                                           0.033731
# 2                                          -0.147673
#
# [3 rows x 83 columns]

# %% [markdown]
# ## Deletion of column data

# %% [markdown]
# The column `Weissman2014.CRISPRi.Growth.phenotype..mean.of.top.3.gammas.` will be deleted because most of the hits in this CRISPRi screen are underpowered.

# %%
ts_score = ts_score.drop('Weissman2014.CRISPRi.Growth.phenotype..mean.of.top.3.gammas.', axis=1)

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Remove NaN Columns

# %% [markdown]
# Define a function `percent_nan` to calculate the **percentage of NaN values** in the column.

# %%
def percent_nan(list):
    return (sum(np.isnan(list))/len(list))

# %% [markdown]
# Apply `percent_nan` to all columns of the `ts_score` table and calculate percentage of NaN values for each column and rank them from highest to lowest.

# %%
nan_check  = ts_score.drop(['Gene', 'Entrez.GeneID', 'ENSEMBL_ID'], 
                           axis=1).apply(percent_nan)
nan_check.sort_values(ascending = False).head(30)
# Out:
# Campbell2018.LAML.pvalues                                       0.937500
# Campbell2018.PANCANCER.pvalues                                  0.937500
# Campbell2018.Combined.pvalues                                   0.937500
# Wallace2016.DEseq2.P.Value                                      0.760417
# Wallace2016.DEseq2.Log2.Fold.Change                             0.760417
# Elledge2019.HMEC.FDR.drop                                       0.166667
# Elledge2019.HPNE.Average.Log2.Drop                              0.166667
# Elledge2019.HPNE.FDR.drop                                       0.166667
# Elledge2019.HMEC.Average.Log2FC.Drop(desc)                      0.166667
# Elledge2019.HMEC.Combined.pvalue.drop                           0.166667
# Elledge2019.HPNE.Combined.pvalue.drop                           0.166667
# Brummelkamp.hap1.GTS.ratio                                      0.093750
# Brummelkamp.kbm7.GTS.ratio                                      0.093750
# Sabbatini2015.Raji.CS                                           0.031250
# Sabbatini2015.KBM7.CS                                           0.031250
# Sabbatini2015.KBM7.adjusted.p.value                             0.031250
# Sabbatini2015.K562.CS                                           0.031250
# Sabbatini2015.K562.adjusted.p.value                             0.031250
# Sabbatini2015.Jiyoye.CS                                         0.031250
# Sabbatini2015.Jiyoye.adjusted.p.value                           0.031250
# Sabbatini2015.Raji.adjusted.p.value                             0.031250
# Weissman2014.CRISPRa.Growth.phenotype..mean.of.top.3.gammas.    0.020833
# Sabbatini2017.OCI.AML3                                          0.000000
# Doench2018.Average.LFC                                          0.000000
# Sabbatini2017.SKM.threshold                                     0.000000
# Sabbatini2017.TF.1                                              0.000000
# Elledge2019.HMEC.Average.threshold                              0.000000
# Sabbatini2017.TF.1.threshold                                    0.000000
# Sabbatini2017.THP.1                                             0.000000
# Sabbatini2017.THP.1.threshold                                   0.000000
# dtype: float64

# %% [markdown]
# From the result above we can see the follow columns have 75% or above of data that are missing (labeled as NaN):
# - `Campbell2018.LAML.pvalues`
# - `Campbell2018.PANCANCER.pvalues`
# - `Campbell2018.Combined.pvalues`
# - `Wallace2016.DEseq2.P.Value`
# - `Wallace2016.DEseq2.Log2.Fold.Change`

# %% [markdown]
# Drop the 5 columns that have 75% or more NaN values and store the resulting table as `ts_score_cleaned_nan`.

# %%
ts_score_cleaned_nan = ts_score.drop(nan_check[nan_check > 0.75].index.tolist(), axis=1)

# %% [markdown]
# ### Remove Zero Variance Columns

# %% [markdown]
# Calculate the variance of each column.

# %%
col_var = ts_score_cleaned_nan.drop(['Gene', 'Entrez.GeneID', 'ENSEMBL_ID'], 
                           axis=1).apply(np.var)
col_var.head(30)
# Out:
# Brummelkamp.hap1.GTS.ratio                                      1.466810e-02
# Brummelkamp.hap1.GTS.threshold                                  3.993056e-02
# Brummelkamp.kbm7.GTS.ratio                                      1.336673e-02
# Brummelkamp.kbm7.GTS.threshold                                  2.039931e-02
# Chen2019.CS.pos.score                                           9.004844e-02
# Chen2019.pos.p.value                                            7.820765e-02
# Chen2019.pos.p.value.threshold                                  3.027344e-02
# Chen2019.pos.fdr                                                7.668305e-04
# Chen2019.pos.rank                                               2.781835e+07
# Weissman2014.CRISPRa.Growth.phenotype..mean.of.top.3.gammas.    1.188182e-03
# Weissman2014.CRISPRa.Growth.phenotype.threshold                 6.759983e-02
# Doench2018.Average.LFC                                          1.392407e-01
# Doench2018.Average.negative.log.p.values.                       3.748032e-01
# Doench2018.Average.negative.log.p.values.threshold              1.457248e-01
# Elledge2013.TUSON_p_value_TSG                                   1.474938e-01
# Elledge2013.TUSON_p_value_TSG.threshold                         1.245660e-01
# Elledge2013.TUSON_q_value_TSG                                   4.431371e-02
# Elledge2013.TSG_Probability_LASSO                               4.349823e-02
# Elledge2019.HMEC.Average.Log2FC.Drop(desc)                      6.368693e-01
# Elledge2019.HMEC.Combined.pvalue.drop                           1.162825e-01
# Elledge2019.HMEC.FDR.drop                                       1.851086e-01
# Elledge2019.HMEC.Average.threshold                              1.523438e-01
# Elledge2019.HPNE.Average.Log2.Drop                              1.289654e+00
# Elledge2019.HPNE.Combined.pvalue.drop                           1.213752e-01
# Elledge2019.HPNE.FDR.drop                                       9.972724e-02
# Elledge2019.HPNE.Average.threshold                              8.496094e-02
# Sabbatini2015.KBM7.CS                                           3.305674e-01
# Sabbatini2015.KBM7.adjusted.p.value                             9.780071e-02
# Sabbatini2015.KBM7.threshold                                    0.000000e+00
# Sabbatini2015.K562.CS                                           5.706186e-01
# dtype: float64

# %% [markdown]
# Drop the colunns that have variance = 0 and store the resulting table as `ts_score_cleaned_var`.

# %%
ts_score_cleaned_var = ts_score_cleaned_nan.drop(col_var[col_var == 0].index.tolist(), axis=1)
ts_score_cleaned_var.head()
# Out:
#      Gene  Entrez.GeneID       ENSEMBL_ID  Brummelkamp.hap1.GTS.ratio  \
# 0   POLD2         5425.0  ENSG00000106628                    0.246339
# 1    EZH2         2146.0  ENSG00000106462                    0.414478
# 2   PTCD1        26024.0  ENSG00000106246                    0.486842
# 3    MCM7         4176.0  ENSG00000166508                    0.077803
# 4  NUP205            NaN  ENSG00000155561                    0.069801
#
#    Brummelkamp.hap1.GTS.threshold  Brummelkamp.kbm7.GTS.ratio  \
# 0                               0                    0.207792
# 1                               0                    0.211823
# 2                               0                    0.488024
# 3                               0                    0.087719
# 4                               0                    0.048443
#
#    Brummelkamp.kbm7.GTS.threshold  Chen2019.CS.pos.score  \
# 0                               0                0.52414
# 1                               0                0.61422
# 2                               0                0.98863
# 3                               0                0.72494
# 4                               0                0.98416
#
#    Chen2019.pos.p.value  Chen2019.pos.p.value.threshold  ...  \
# 0               0.52419                               0  ...
# 1               0.61400                               0  ...
# 2               0.98870                               0  ...
# 3               0.72481                               0  ...
# 4               0.98426                               0  ...
#
#    Sabbatini2017.SKM.1  Sabbatini2017.SKM.threshold  Sabbatini2017.TF.1  \
# 0               -2.306                            0              -3.450
# 1               -1.706                            0              -2.087
# 2               -0.975                            0              -1.820
# 3               -1.879                            0              -2.898
# 4               -2.369                            0              -2.675
#
#    Sabbatini2017.THP.1  Wallace2016.threshold  \
# 0               -3.567                      1
# 1               -1.605                      0
# 2               -1.544                      0
# 3               -3.325                      0
# 4               -2.244                      0
#
#    Weissman2016a.mean.Replicate1_n_2.Mann.Whitney.p.value  \
# 0                                           0.137059
# 1                                           0.798109
# 2                                           0.186927
# 3                                           0.529921
# 4                                           0.050028
#
#    Weissman2016a.CS.average.phenotype.of.strongest.3.2  \
# 0                                          -0.012419
# 1                                          -0.000228
# 2                                          -0.016081
# 3                                          -0.014970
# 4                                           0.005240
#
#    Weissman2016a.threshold  Weissman2016i.Rep1_2.Mann.Whitney.p.value  \
# 0                        0                               7.450000e-06
# 1                        0                               2.193387e-02
# 2                        0                               2.991830e-04
# 3                        0                               3.089643e-01
# 4                        0                               2.220000e-07
#
#    Weissman2016i.average.phenotype.of.strongest.3 guides.comb(avg CS for replicate 1 and 2)
# 0                                          -0.205830
# 1                                           0.033731
# 2                                          -0.147673
# 3                                          -0.069984
# 4                                          -0.339325
#
# [5 rows x 63 columns]

# %% [markdown]
# ### Remove Zero Columns

# %% [markdown]
# Define a function `percent_zero` to calculate the __percentage of zeros__ in the column given.

# %%
def percent_zero(list):
    return ((len(list) - np.count_nonzero(list))/len(list))

# %% [markdown]
# Apply `percent_zero` to all columns of the ts_score table and calculate percentage of zero values for each column and rank them from highest to lowest.

# %%
zeros_check = ts_score_cleaned_var.drop(['Gene', 'Entrez.GeneID', 'ENSEMBL_ID'], axis=1).apply(percent_zero)
zeros_check.sort_values(ascending = False).head(20)
# Out:
# Sabbatini2015.Raji.threshold                          0.989583
# Sabbatini2015.Jiyoye.threshold                        0.979167
# Brummelkamp.kbm7.GTS.threshold                        0.979167
# Sabbatini2017.MOLM.13.threshold                       0.968750
# Sabbatini2017.SKM.threshold                           0.968750
# Chen2019.pos.p.value.threshold                        0.968750
# Brummelkamp.hap1.GTS.threshold                        0.958333
# Sabbatini2015.K562.threshold                          0.947917
# Weissman2014.CRISPRa.Growth.phenotype.threshold       0.927083
# Elledge2019.HPNE.Average.threshold                    0.906250
# Elledge2013.TUSON_p_value_TSG.threshold               0.854167
# Doench2018.Average.negative.log.p.values.threshold    0.822917
# Elledge2019.HMEC.Average.threshold                    0.812500
# Wallace2016.threshold                                 0.781250
# Weissman2016a.threshold                               0.604167
# Elledge2019.HMEC.Average.Log2FC.Drop(desc)            0.020833
# Sabbatini2015.K562.CS                                 0.010417
# Brummelkamp.kbm7.GTS.ratio                            0.010417
# Elledge2019.HMEC.FDR.drop                             0.000000
# Elledge2019.HMEC.Combined.pvalue.drop                 0.000000
# dtype: float64

# %% [markdown]
# From the result above we can see the following columns have 60% or above of data that are 0 (they are all threshold columns):
#
# - `Sabbatini2015.Raji.threshold`
# - `Sabbatini2015.Jiyoye.threshold`
# - `Brummelkamp.kbm7.GTS.threshold`
# - `Sabbatini2017.MOLM.13.threshold`
# - `Sabbatini2017.SKM.threshold`
# - `Chen2019.pos.p.value.threshold`
# - `Brummelkamp.hap1.GTS.threshold`
# - `Sabbatini2015.K562.threshold`
# - `Weissman2014.CRISPRa.Growth.phenotype.threshold`
# - `Elledge2019.HPNE.Average.threshold`
# - `Elledge2013.TUSON_p_value_TSG.threshold`
# - `Doench2018.Average.negative.log.p.values.threshold`
# - `Elledge2019.HMEC.Average.threshold`
# - `Wallace2016.threshold`
# - `Weissman2016a.threshold`

# %% [markdown]
# Remove the columns above that have more than 60% zeros.

# %%
ts_score_cleaned_zero = ts_score_cleaned_var.drop(zeros_check[zeros_check > 0.6].index.tolist(), axis=1)
ts_score_cleaned_zero.columns.tolist()
# Out:
# ['Gene',
#  'Entrez.GeneID',
#  'ENSEMBL_ID',
#  'Brummelkamp.hap1.GTS.ratio',
#  'Brummelkamp.kbm7.GTS.ratio',
#  'Chen2019.CS.pos.score',
#  'Chen2019.pos.p.value',
#  'Chen2019.pos.fdr',
#  'Chen2019.pos.rank',
#  'Weissman2014.CRISPRa.Growth.phenotype..mean.of.top.3.gammas.',
#  'Doench2018.Average.LFC',
#  'Doench2018.Average.negative.log.p.values.',
#  'Elledge2013.TUSON_p_value_TSG',
#  'Elledge2013.TUSON_q_value_TSG',
#  'Elledge2013.TSG_Probability_LASSO',
#  'Elledge2019.HMEC.Average.Log2FC.Drop(desc)',
#  'Elledge2019.HMEC.Combined.pvalue.drop',
#  'Elledge2019.HMEC.FDR.drop',
#  'Elledge2019.HPNE.Average.Log2.Drop',
#  'Elledge2019.HPNE.Combined.pvalue.drop',
#  'Elledge2019.HPNE.FDR.drop',
#  'Sabbatini2015.KBM7.CS',
#  'Sabbatini2015.KBM7.adjusted.p.value',
#  'Sabbatini2015.K562.CS',
#  'Sabbatini2015.K562.adjusted.p.value',
#  'Sabbatini2015.Jiyoye.CS',
#  'Sabbatini2015.Jiyoye.adjusted.p.value',
#  'Sabbatini2015.Raji.CS',
#  'Sabbatini2015.Raji.adjusted.p.value',
#  'Sabbatini2017.EOL.1',
#  'Sabbatini2017.HEL',
#  'Sabbatini2017.MOLM.13',
#  'Sabbatini2017.MonoMac1',
#  'Sabbatini2017.MV411.threshold',
#  'Sabbatini2017.NB4.rep1',
#  'Sabbatini2017.NB4.rep2',
#  'Sabbatini2017.OCI.AML2',
#  'Sabbatini2017.OCI.AML3',
#  'Sabbatini2017.OCI.AML5',
#  'Sabbatini2017.P31.FUJ',
#  'Sabbatini2017.PL.21',
#  'Sabbatini2017.SKM.1',
#  'Sabbatini2017.TF.1',
#  'Sabbatini2017.THP.1',
#  'Weissman2016a.mean.Replicate1_n_2.Mann.Whitney.p.value',
#  'Weissman2016a.CS.average.phenotype.of.strongest.3.2',
#  'Weissman2016i.Rep1_2.Mann.Whitney.p.value',
#  'Weissman2016i.average.phenotype.of.strongest.3 guides.comb(avg CS for replicate 1 and 2)']

# %% [markdown]
# Note that there is one more threshold column (probably with all 1 values) that need to be manually removed.

# %%
ts_score_cleaned_thrsh = ts_score_cleaned_zero.drop('Sabbatini2017.MV411.threshold', axis=1)
ts_score_cleaned_thrsh.head()
# Out:
#      Gene  Entrez.GeneID       ENSEMBL_ID  Brummelkamp.hap1.GTS.ratio  \
# 0   POLD2         5425.0  ENSG00000106628                    0.246339
# 1    EZH2         2146.0  ENSG00000106462                    0.414478
# 2   PTCD1        26024.0  ENSG00000106246                    0.486842
# 3    MCM7         4176.0  ENSG00000166508                    0.077803
# 4  NUP205            NaN  ENSG00000155561                    0.069801
#
#    Brummelkamp.kbm7.GTS.ratio  Chen2019.CS.pos.score  Chen2019.pos.p.value  \
# 0                    0.207792                0.52414               0.52419
# 1                    0.211823                0.61422               0.61400
# 2                    0.488024                0.98863               0.98870
# 3                    0.087719                0.72494               0.72481
# 4                    0.048443                0.98416               0.98426
#
#    Chen2019.pos.fdr  Chen2019.pos.rank  \
# 0          0.999997               9935
# 1          0.999997              11628
# 2          0.999997              18786
# 3          0.999997              13679
# 4          0.999997              18676
#
#    Weissman2014.CRISPRa.Growth.phenotype..mean.of.top.3.gammas.  ...  \
# 0                                          -0.001149             ...
# 1                                           0.034245             ...
# 2                                          -0.049917             ...
# 3                                          -0.099647             ...
# 4                                          -0.013492             ...
#
#    Sabbatini2017.OCI.AML5  Sabbatini2017.P31.FUJ  Sabbatini2017.PL.21  \
# 0                  -3.504                 -3.275               -2.019
# 1                  -1.001                  0.178                0.919
# 2                  -1.967                 -2.010               -1.250
# 3                  -3.472                 -3.049               -1.725
# 4                  -2.165                 -2.378               -1.174
#
#    Sabbatini2017.SKM.1  Sabbatini2017.TF.1  Sabbatini2017.THP.1  \
# 0               -2.306              -3.450               -3.567
# 1               -1.706              -2.087               -1.605
# 2               -0.975              -1.820               -1.544
# 3               -1.879              -2.898               -3.325
# 4               -2.369              -2.675               -2.244
#
#    Weissman2016a.mean.Replicate1_n_2.Mann.Whitney.p.value  \
# 0                                           0.137059
# 1                                           0.798109
# 2                                           0.186927
# 3                                           0.529921
# 4                                           0.050028
#
#    Weissman2016a.CS.average.phenotype.of.strongest.3.2  \
# 0                                          -0.012419
# 1                                          -0.000228
# 2                                          -0.016081
# 3                                          -0.014970
# 4                                           0.005240
#
#    Weissman2016i.Rep1_2.Mann.Whitney.p.value  \
# 0                               7.450000e-06
# 1                               2.193387e-02
# 2                               2.991830e-04
# 3                               3.089643e-01
# 4                               2.220000e-07
#
#    Weissman2016i.average.phenotype.of.strongest.3 guides.comb(avg CS for replicate 1 and 2)
# 0                                          -0.205830
# 1                                           0.033731
# 2                                          -0.147673
# 3                                          -0.069984
# 4                                          -0.339325
#
# [5 rows x 47 columns]

# %% [markdown]
# ### Save Cleaned Dataframe

# %% [markdown]
# Save this cleaned dataframe to a new `.csv` file

# %%
ts_score_cleaned_thrsh.to_csv(r'../data/Rank_variables_master_list_cleaned.csv')

# %% [markdown]
# ### Rename the Columns

# %% [markdown]
# The columns of the cleaned dataframe need to be renamed in order to achieve both conciseness and clarity. The new column names shall be constructed to keep the following features:
# - four-letter abbreviation of the communication author's last name
# - type of cell line used (if applicable)
# - type of statistical manipulation applied, etc. avg, combined, logm (if applicable)
# - type of scores/measures applied, etc. GTS (Gene Trap Score), cs(crispr score), pvalue, fdr (false discovery rate)

# %%
col_names = {'Brummelkamp.hap1.GTS.ratio': 'Brum.HAP1.GTS',
             'Brummelkamp.kbm7.GTS.ratio': 'Brum.KBM7.GTS',
             'Chen2019.CS.pos.score': 'Chen.cs',
             'Chen2019.pos.fdr': 'Chen.fdr', 
             'Chen2019.pos.p.value': 'Chen.pvalue',
             'Chen2019.pos.rank': 'Chen.ts.rank',
             'Doench2018.Average.LFC': 'Doen.avg.LFC',
             'Doench2018.Average.negative.log.p.values.': 'Doen.avg.neg.log.pvalue',
             'Elledge2013.TUSON_p_value_TSG': 'Elle13.pvalue',
             'Elledge2013.TUSON_q_value_TSG': 'Elle13.fdr',
             'Elledge2013.TSG_Probability_LASSO': 'Elle13.lasso.prob',
             'Elledge2019.HMEC.Average.Log2FC.Drop(desc)': 'Elle18.HMEC.avg.LFC',
             'Elledge2019.HMEC.Combined.pvalue.drop': 'Elle18.HMEC.combined.pvalue', 
             'Elledge2019.HMEC.FDR.drop': 'Elle19.HMEC.fdr',
             'Elledge2019.HPNE.Average.Log2.Drop': 'Elle18.HPNE.avg.LFC',
             'Elledge2019.HPNE.Combined.pvalue.drop': 'Elle18.HPNE.Combined.pvalue',
             'Elledge2019.HPNE.FDR.drop': 'Elle19.HPNE.fdr',
             'Sabbatini2015.KBM7.CS': 'Sabb15.KBM7.cs',
             'Sabbatini2015.KBM7.adjusted.p.value': 'Sabb15.KBM7.fdr',
             'Sabbatini2015.K562.CS': 'Sabb15.K562.cs',
             'Sabbatini2015.K562.adjusted.p.value': 'Sabb15.K562.fdr',
             'Sabbatini2015.Jiyoye.CS': 'Sabb15.Jiyoye.cs', 
             'Sabbatini2015.Jiyoye.adjusted.p.value': 'Sabb15.Jiyoye.fdr',
             'Sabbatini2015.Raji.CS': 'Sabb15.Raji.cs',
             'Sabbatini2015.Raji.adjusted.p.value': 'Sabb15.Raji.fdr',
             'Sabbatini2017.EOL.1': 'Sabb17.EOL1', 
             'Sabbatini2017.HEL': 'Sabb17.HEL',
             'Sabbatini2017.MOLM.13': 'Sabb17.MOLM13',
             'Sabbatini2017.MonoMac1': 'Sabb17.MonoMac1',
             'Sabbatini2017.NB4.rep1': 'Sabb17.NB4.rep1',
             'Sabbatini2017.NB4.rep2': 'Sabb17.NB4.rep2', 
             'Sabbatini2017.OCI.AML2': 'Sabb17.OCI.AML2',
             'Sabbatini2017.OCI.AML3': 'Sabb17.OCI.AML3', 
             'Sabbatini2017.OCI.AML5': 'Sabb17.OCI.AML5',
             'Sabbatini2017.P31.FUJ': 'Sabb17.P31.FUJ', 
             'Sabbatini2017.PL.21': 'Sabb17.PL21', 
             'Sabbatini2017.SKM.1': 'Sabb17.SKM1',
             'Sabbatini2017.TF.1': 'Sabb17.TF1', 
             'Sabbatini2017.THP.1': 'Sabb17.THP1',
             'Weissman2014.CRISPRa.Growth.phenotype..mean.of.top.3.gammas.': 'Weis14.csa.avg',
             'Weissman2016a.mean.Replicate1_n_2.Mann.Whitney.p.value': 'Weis16.csa.MW.pvalue',
             'Weissman2016a.CS.average.phenotype.of.strongest.3.2': 'Weis16.csa.avg',
             'Weissman2016i.Rep1_2.Mann.Whitney.p.value': 'Weis16.csi.MW.pvalue',
             'Weissman2016i.average.phenotype.of.strongest.3 guides.comb(avg CS for replicate 1 and 2)': 'Weis16.csi.avg'}

# %%
ts_score_cleaned = ts_score_cleaned_thrsh.rename(columns = col_names)

# %%
ts_score_cleaned.columns
# Out:
# Index(['Gene', 'Entrez.GeneID', 'ENSEMBL_ID', 'Brum.HAP1.GTS', 'Brum.KBM7.GTS',
#        'Chen.cs', 'Chen.pvalue', 'Chen.fdr', 'Chen.ts.rank', 'Weis14.csa.avg',
#        'Doen.avg.LFC', 'Doen.avg.neg.log.pvalue', 'Elle13.pvalue',
#        'Elle13.fdr', 'Elle13.lasso.prob', 'Elle18.HMEC.avg.LFC',
#        'Elle18.HMEC.combined.pvalue', 'Elle19.HMEC.fdr', 'Elle18.HPNE.avg.LFC',
#        'Elle18.HPNE.Combined.pvalue', 'Elle19.HPNE.fdr', 'Sabb15.KBM7.cs',
#        'Sabb15.KBM7.fdr', 'Sabb15.K562.cs', 'Sabb15.K562.fdr',
#        'Sabb15.Jiyoye.cs', 'Sabb15.Jiyoye.fdr', 'Sabb15.Raji.cs',
#        'Sabb15.Raji.fdr', 'Sabb17.EOL1', 'Sabb17.HEL', 'Sabb17.MOLM13',
#        'Sabb17.MonoMac1', 'Sabb17.NB4.rep1', 'Sabb17.NB4.rep2',
#        'Sabb17.OCI.AML2', 'Sabb17.OCI.AML3', 'Sabb17.OCI.AML5',
#        'Sabb17.P31.FUJ', 'Sabb17.PL21', 'Sabb17.SKM1', 'Sabb17.TF1',
#        'Sabb17.THP1', 'Weis16.csa.MW.pvalue', 'Weis16.csa.avg',
#        'Weis16.csi.MW.pvalue', 'Weis16.csi.avg'],
#       dtype='object')

# %%
ts_score_cleaned.to_csv(r'../data/Rank_variables_master_list_clean_renamed.csv')

# %% [markdown]
# ## Imputation (Replace NaNs)

# %% [markdown]
# ### Median

# %%
def nan_to_median(df):
    new = df.copy()
    cols = new.drop(['Gene','Entrez.GeneID', 'ENSEMBL_ID'], axis=1).columns.tolist()
    medians = new.drop(['Gene','Entrez.GeneID', 'ENSEMBL_ID'], axis=1).apply(np.nanmedian)
    for i in cols:
        new[i] = new[i].replace(np.nan, medians[i])
    return new

# %%
ts_score_median_imputation = nan_to_median(ts_score_cleaned)
ts_score_median_imputation.head()
# Out:
#      Gene  Entrez.GeneID       ENSEMBL_ID  Brum.HAP1.GTS  Brum.KBM7.GTS  \
# 0   POLD2         5425.0  ENSG00000106628       0.246339       0.207792
# 1    EZH2         2146.0  ENSG00000106462       0.414478       0.211823
# 2   PTCD1        26024.0  ENSG00000106246       0.486842       0.488024
# 3    MCM7         4176.0  ENSG00000166508       0.077803       0.087719
# 4  NUP205            NaN  ENSG00000155561       0.069801       0.048443
#
#    Chen.cs  Chen.pvalue  Chen.fdr  Chen.ts.rank  Weis14.csa.avg  ...  \
# 0  0.52414      0.52419  0.999997          9935       -0.001149  ...
# 1  0.61422      0.61400  0.999997         11628        0.034245  ...
# 2  0.98863      0.98870  0.999997         18786       -0.049917  ...
# 3  0.72494      0.72481  0.999997         13679       -0.099647  ...
# 4  0.98416      0.98426  0.999997         18676       -0.013492  ...
#
#    Sabb17.OCI.AML5  Sabb17.P31.FUJ  Sabb17.PL21  Sabb17.SKM1  Sabb17.TF1  \
# 0           -3.504          -3.275       -2.019       -2.306      -3.450
# 1           -1.001           0.178        0.919       -1.706      -2.087
# 2           -1.967          -2.010       -1.250       -0.975      -1.820
# 3           -3.472          -3.049       -1.725       -1.879      -2.898
# 4           -2.165          -2.378       -1.174       -2.369      -2.675
#
#    Sabb17.THP1  Weis16.csa.MW.pvalue  Weis16.csa.avg  Weis16.csi.MW.pvalue  \
# 0       -3.567              0.137059       -0.012419          7.450000e-06
# 1       -1.605              0.798109       -0.000228          2.193387e-02
# 2       -1.544              0.186927       -0.016081          2.991830e-04
# 3       -3.325              0.529921       -0.014970          3.089643e-01
# 4       -2.244              0.050028        0.005240          2.220000e-07
#
#    Weis16.csi.avg
# 0       -0.205830
# 1        0.033731
# 2       -0.147673
# 3       -0.069984
# 4       -0.339325
#
# [5 rows x 47 columns]

# %%
ts_score_median_imputation
# Out:
#         Gene  Entrez.GeneID       ENSEMBL_ID  Brum.HAP1.GTS  Brum.KBM7.GTS  \
# 0      POLD2         5425.0  ENSG00000106628       0.246339       0.207792
# 83    ZNF789       285989.0  ENSG00000198556       0.489899       0.467914
# 84    PTPN12         5782.0  ENSG00000127947       0.587347       0.589197
# 85    ZDHHC4        55146.0  ENSG00000136247       0.500482       0.508772
# 86      IRF5         3663.0  ENSG00000128604       0.575893       0.508704
# 87     TRIP6         7205.0  ENSG00000087077       0.512332       0.474304
# 88       SP4         6671.0  ENSG00000105866       0.511613       0.543186
# 89     JAZF1       221895.0  ENSG00000153814       0.533993       0.493528
# 90     AP5Z1         9907.0  ENSG00000242802       0.529167       0.581395
# 91    LUC7L2        51631.0              NaN       0.504202       0.494515
# 92     PLOD3         8985.0  ENSG00000106397       0.518148       0.520548
# 93      ISPD            NaN  ENSG00000214960       0.496780       0.495055
# 94      TARP            NaN              NaN       0.504202       0.494515
# 95  TMEM120A        83862.0              NaN       0.504202       0.494515
#
#      Chen.cs  Chen.pvalue  Chen.fdr  Chen.ts.rank  Weis14.csa.avg  ...  \
# 0   0.524140     0.524190  0.999997          9935       -0.001149  ...
# 1   0.614220     0.614000  0.999997         11628        0.034245  ...
# 2   0.988630     0.988700  0.999997         18786       -0.049917  ...
# 3   0.724940     0.724810  0.999997         13679       -0.099647  ...
# 4   0.984160     0.984260  0.999997         18676       -0.013492  ...
# 5   0.423200     0.433060  0.999997          8208        0.009153  ...
# 6   0.003058     0.009031  0.898840           187       -0.017155  ...
# 7   0.940260     0.940080  0.999997         17806       -0.009182  ...
# 8   0.074559     0.130170  0.987051          2515       -0.026189  ...
# 9   0.744320     0.744070  0.999997         14037       -0.007685  ...
# 10  0.463160     0.467440  0.999997          8845       -0.005007  ...
# 11  0.484940     0.487130  0.999997          9206       -0.018194  ...
# 12  0.807260     0.807250  0.999997         15232       -0.087811  ...
# 13  0.990810     0.990820  0.999997         18831       -0.028035  ...
# 14  0.996550     0.996580  0.999997         19010        0.008693  ...
# 15  0.838300     0.837990  0.999997         15834        0.013883  ...
# 16  0.092595     0.155990  0.988199          3015        0.010608  ...
# 17  0.058508     0.106890  0.982247          2075        0.035735  ...
# 18  0.901830     0.901450  0.999997         17063       -0.006082  ...
# 19  0.334480     0.362230  0.999997          6862       -0.007664  ...
# 20  0.796560     0.796570  0.999997         14997        0.041825  ...
# 21  0.233450     0.289920  0.999997          5533       -0.017525  ...
# 22  0.224710     0.283960  0.999997          5419       -0.039306  ...
# 23  0.569160     0.568910  0.999997         10772       -0.054902  ...
# 24  0.485520     0.487640  0.999997          9214        0.016389  ...
# 25  0.565810     0.565520  0.999997         10708       -0.001010  ...
# 26  0.429690     0.438490  0.999997          8305        0.000186  ...
# 27  0.712020     0.711810  0.999997         13443       -0.016338  ...
# 28  0.402000     0.415450  0.999997          7875        0.072370  ...
# 29  0.070786     0.124720  0.987051          2406       -0.038957  ...
# ..       ...          ...       ...           ...             ...  ...
# 66  0.505530     0.506340  0.999997          9584        0.012369  ...
# 67  0.804990     0.804950  0.999997         15182       -0.002830  ...
# 68  0.472590     0.475840  0.999997          9009        0.007585  ...
# 28        0.015522
# 29       -0.025678
# ..             ...
# 66       -0.030158
# 67        0.011794
# 68        0.024941
# 69        0.032284
# 70       -0.036265
# 71       -0.026211
# 72        0.022040
# 73        0.005722
# 74       -0.015290
# 75       -0.004549
# 76       -0.024774
# 77       -0.010173
# 78       -0.009681
# 79       -0.007905
# 80        0.000280
# 81       -0.007981
# 82       -0.001067
# 83        0.028061
# 84       -0.054847
# 85       -0.030523
# 86        0.007845
# 87       -0.038139
# 88       -0.042155
# 89       -0.081982
# 90       -0.031518
# 91        0.018418
# 92       -0.014343
# 93       -0.052490
# 94       -0.009949
# 95        0.005924
#
# [96 rows x 47 columns]

# %% [markdown]
# Now see if the imputation had worked by checking the first row `Brum.HAP1.GTS`.

# %%
ts_score_cleaned[np.isnan(ts_score_cleaned["Brum.HAP1.GTS"].tolist())]
# Out:
#         Gene  Entrez.GeneID       ENSEMBL_ID  Brum.HAP1.GTS  Brum.KBM7.GTS  \
# 32   RABGEF1        27342.0              NaN            NaN            NaN
# 34   DNAJC30        84277.0  ENSG00000176410            NaN            NaN
# 75   ZSCAN25       221785.0              NaN            NaN            NaN
# 77    TNRC18            NaN              NaN            NaN            NaN
# 79     CALN1        83698.0              NaN            NaN            NaN
# 82   C1GALT1            NaN              NaN            NaN            NaN
# 91    LUC7L2        51631.0              NaN            NaN            NaN
# 94      TARP            NaN              NaN            NaN            NaN
# 95  TMEM120A        83862.0              NaN            NaN            NaN
#
#     Chen.cs  Chen.pvalue  Chen.fdr  Chen.ts.rank  Weis14.csa.avg  ...  \
# 32  0.54397      0.54361  0.999997         10300        0.013104  ...
# 34  0.89391      0.89346  0.999997         16891        0.001629  ...
# 75  0.48859      0.49046  0.999997          9276       -0.007927  ...
# 77  0.78966      0.78968  0.999997         14875       -0.005101  ...
# 79  0.63701      0.63683  0.999997         12038             NaN  ...
# 82  0.76473      0.76453  0.999997         14422       -0.017888  ...
# 91  0.36035      0.38215  0.999997          7236       -0.013031  ...
# 94  0.66453      0.66419  0.999997         12533             NaN  ...
# 95  0.82131      0.82120  0.999997         15499       -0.014349  ...
#
#     Sabb17.OCI.AML5  Sabb17.P31.FUJ  Sabb17.PL21  Sabb17.SKM1  Sabb17.TF1  \
# 32           -0.900          -0.438       -1.109       -1.409      -0.544
# 34            0.191          -0.124       -0.326       -0.644       0.190
# 75           -0.037          -0.376        0.098       -0.237      -0.143
# 77           -0.699          -0.233       -1.256       -1.005      -1.393
# 79            0.251          -0.229        0.256       -0.250      -0.079
# 82            0.505           0.464        0.289        0.105       0.536
# 91           -1.269          -0.991       -0.914       -0.946      -2.606
# 94            0.113           0.455        0.045        0.048       0.575
# 95            0.184          -0.161       -0.322       -0.337      -0.140
#
#     Sabb17.THP1  Weis16.csa.MW.pvalue  Weis16.csa.avg  Weis16.csi.MW.pvalue  \
# 32       -1.933              0.003739       -0.027808              0.704017
# 34       -0.288              0.406469        0.008781              0.616128
# 75       -0.164              0.611917        0.008821              0.986175
# 77       -0.160              0.010632       -0.033607              0.176836
# 79       -0.327              0.019361       -0.022015              0.286409
# 82        0.615              0.291431        0.006242              0.404980
# 91       -0.557              0.023538       -0.015354              0.546132
# 94        0.650              0.539946       -0.012642              0.443288
# 95       -0.157              0.155952       -0.004993              0.736046
#
#     Weis16.csi.avg
# 32        0.013199
# 34       -0.031020
# 75       -0.004549
# 77       -0.010173
# 79       -0.007905
# 82       -0.001067
# 91        0.018418
# 94       -0.009949
# 95        0.005924
#
# [9 rows x 47 columns]

# %%
ts_score_median_imputation.loc[ts_score_cleaned[np.isnan(ts_score_cleaned["Brum.HAP1.GTS"].tolist())].index]
# Out:
#         Gene  Entrez.GeneID       ENSEMBL_ID  Brum.HAP1.GTS  Brum.KBM7.GTS  \
# 32   RABGEF1        27342.0              NaN       0.504202       0.494515
# 34   DNAJC30        84277.0  ENSG00000176410       0.504202       0.494515
# 75   ZSCAN25       221785.0              NaN       0.504202       0.494515
# 77    TNRC18            NaN              NaN       0.504202       0.494515
# 79     CALN1        83698.0              NaN       0.504202       0.494515
# 82   C1GALT1            NaN              NaN       0.504202       0.494515
# 91    LUC7L2        51631.0              NaN       0.504202       0.494515
# 94      TARP            NaN              NaN       0.504202       0.494515
# 95  TMEM120A        83862.0              NaN       0.504202       0.494515
#
#     Chen.cs  Chen.pvalue  Chen.fdr  Chen.ts.rank  Weis14.csa.avg  ...  \
# 32  0.54397      0.54361  0.999997         10300        0.013104  ...
# 34  0.89391      0.89346  0.999997         16891        0.001629  ...
# 75  0.48859      0.49046  0.999997          9276       -0.007927  ...
# 77  0.78966      0.78968  0.999997         14875       -0.005101  ...
# 79  0.63701      0.63683  0.999997         12038       -0.007076  ...
# 82  0.76473      0.76453  0.999997         14422       -0.017888  ...
# 91  0.36035      0.38215  0.999997          7236       -0.013031  ...
# 94  0.66453      0.66419  0.999997         12533       -0.007076  ...
# 95  0.82131      0.82120  0.999997         15499       -0.014349  ...
#
#     Sabb17.OCI.AML5  Sabb17.P31.FUJ  Sabb17.PL21  Sabb17.SKM1  Sabb17.TF1  \
# 32           -0.900          -0.438       -1.109       -1.409      -0.544
# 34            0.191          -0.124       -0.326       -0.644       0.190
# 75           -0.037          -0.376        0.098       -0.237      -0.143
# 77           -0.699          -0.233       -1.256       -1.005      -1.393
# 79            0.251          -0.229        0.256       -0.250      -0.079
# 82            0.505           0.464        0.289        0.105       0.536
# 91           -1.269          -0.991       -0.914       -0.946      -2.606
# 94            0.113           0.455        0.045        0.048       0.575
# 95            0.184          -0.161       -0.322       -0.337      -0.140
#
#     Sabb17.THP1  Weis16.csa.MW.pvalue  Weis16.csa.avg  Weis16.csi.MW.pvalue  \
# 32       -1.933              0.003739       -0.027808              0.704017
# 34       -0.288              0.406469        0.008781              0.616128
# 75       -0.164              0.611917        0.008821              0.986175
# 77       -0.160              0.010632       -0.033607              0.176836
# 79       -0.327              0.019361       -0.022015              0.286409
# 82        0.615              0.291431        0.006242              0.404980
# 91       -0.557              0.023538       -0.015354              0.546132
# 94        0.650              0.539946       -0.012642              0.443288
# 95       -0.157              0.155952       -0.004993              0.736046
#
#     Weis16.csi.avg
# 32        0.013199
# 34       -0.031020
# 75       -0.004549
# 77       -0.010173
# 79       -0.007905
# 82       -0.001067
# 91        0.018418
# 94       -0.009949
# 95        0.005924
#
# [9 rows x 47 columns]

# %%
np.nanmedian(ts_score_cleaned['Brum.HAP1.GTS'])
# Out:
# 0.5042016810000001

# %%
ts_score_median_imputation.to_csv(r'../data/work_data.csv')

# %% [markdown]
# ### K-NN

# %% [markdown]
# First I would like to see number of NaN for each gene and decide if the k-NN method works for each gene missing some values.

# %%
def num_nan_row(df):
    copy = df.drop(['Entrez.GeneID', 'ENSEMBL_ID'], axis=1)
    copy.index = copy['Gene']
    copy = copy.drop('Gene', axis = 1)
    for i in copy.columns.tolist():
        copy[i] = np.array(np.isnan(df[i]))
    return copy.sum(axis = 1)

# %%
def num_nan_col(df):
    copy = df.drop(['Entrez.GeneID', 'ENSEMBL_ID'], axis=1)
    copy.index = copy['Gene']
    copy = copy.drop('Gene', axis = 1)
    for i in copy.columns.tolist():
        copy[i] = np.array(np.isnan(df[i]))
    return copy.sum(axis = 0)

# %%
nan_byrow = num_nan_row(ts_score_cleaned).sort_values(ascending = False)
nan_byrow.head(25)
# Out:
# Gene
# TARP        17
# ISPD        14
# TMEM120A    10
# TNRC18       8
# C1GALT1      8
# SND1         6
# CCZ1B        6
# ZNF800       6
# CARD11       6
# LMBR1        6
# PHF14        6
# AHR          6
# ZNF12        6
# ZNF862       6
# KMT2C        6
# NUP205       6
# GTF2IRD1     6
# CALN1        3
# DNAJC30      2
# ZSCAN25      2
# LUC7L2       2
# RABGEF1      2
# ZC3HAV1      0
# CCM2         0
# KRIT1        0
# dtype: int64

# %%
nan_byrow/len(nan_byrow)
# Out:
# Gene
# TARP        0.177083
# ISPD        0.145833
# TMEM120A    0.104167
# TNRC18      0.083333
# C1GALT1     0.083333
# SND1        0.062500
# CCZ1B       0.062500
# ZNF800      0.062500
# CARD11      0.062500
# LMBR1       0.062500
# PHF14       0.062500
# AHR         0.062500
# ZNF12       0.062500
# ZNF862      0.062500
# KMT2C       0.062500
# NUP205      0.062500
# GTF2IRD1    0.062500
# CALN1       0.031250
# DNAJC30     0.020833
# ZSCAN25     0.020833
# LUC7L2      0.020833
# RABGEF1     0.020833
# ZC3HAV1     0.000000
# CCM2        0.000000
# KRIT1       0.000000
# BCAP29      0.000000
# TES         0.000000
# TMEM248     0.000000
# BPGM        0.000000
# HIP1        0.000000
#               ...
# ZNF789      0.000000
# PTPN12      0.000000
# ZDHHC4      0.000000
# IRF5        0.000000
# TRIP6       0.000000
# SP4         0.000000
# JAZF1       0.000000
# AP5Z1       0.000000
# PLOD3       0.000000
# BRAF        0.000000
# IGF2BP3     0.000000
# PURB        0.000000
# ATXN7L1     0.000000
# PPIA        0.000000
# SYPL1       0.000000
# LIMK1       0.000000
# SEMA3C      0.000000
# ASL         0.000000
# ZC3HAV1L    0.000000
# PUS7        0.000000
# RALA        0.000000
# CLDN15      0.000000
# KCTD7       0.000000
# CUX1        0.000000
# HOXA10      0.000000
# VKORC1L1    0.000000
# EIF2AK1     0.000000
# AP4M1       0.000000
# TMED4       0.000000
# POLD2       0.000000
# Length: 96, dtype: float64

# %%
nan_bycol = num_nan_col(ts_score_cleaned).sort_values(ascending = False)
nan_bycol.head(25)
# Out:
# Elle18.HMEC.avg.LFC            16
# Elle18.HMEC.combined.pvalue    16
# Elle19.HMEC.fdr                16
# Elle18.HPNE.avg.LFC            16
# Elle18.HPNE.Combined.pvalue    16
# Elle19.HPNE.fdr                16
# Brum.HAP1.GTS                   9
# Brum.KBM7.GTS                   9
# Sabb15.Raji.fdr                 3
# Sabb15.KBM7.cs                  3
# Sabb15.KBM7.fdr                 3
# Sabb15.K562.cs                  3
# Sabb15.Jiyoye.cs                3
# Sabb15.Jiyoye.fdr               3
# Sabb15.Raji.cs                  3
# Sabb15.K562.fdr                 3
# Weis14.csa.avg                  2
# Sabb17.HEL                      0
# Sabb17.EOL1                     0
# Weis16.csa.avg                  0
# Chen.cs                         0
# Chen.pvalue                     0
# Chen.fdr                        0
# Chen.ts.rank                    0
# Doen.avg.LFC                    0
# dtype: int64

# %%
nan_bycol/96
# Out:
# Elle18.HMEC.avg.LFC            0.166667
# Elle18.HMEC.combined.pvalue    0.166667
# Elle19.HMEC.fdr                0.166667
# Elle18.HPNE.avg.LFC            0.166667
# Elle18.HPNE.Combined.pvalue    0.166667
# Elle19.HPNE.fdr                0.166667
# Brum.HAP1.GTS                  0.093750
# Brum.KBM7.GTS                  0.093750
# Sabb15.Raji.fdr                0.031250
# Sabb15.KBM7.cs                 0.031250
# Sabb15.KBM7.fdr                0.031250
# Sabb15.K562.cs                 0.031250
# Sabb15.Jiyoye.cs               0.031250
# Sabb15.Jiyoye.fdr              0.031250
# Sabb15.Raji.cs                 0.031250
# Sabb15.K562.fdr                0.031250
# Weis14.csa.avg                 0.020833
# Sabb17.HEL                     0.000000
# Sabb17.EOL1                    0.000000
# Weis16.csa.avg                 0.000000
# Chen.cs                        0.000000
# Chen.pvalue                    0.000000
# Chen.fdr                       0.000000
# Chen.ts.rank                   0.000000
# Doen.avg.LFC                   0.000000
# Doen.avg.neg.log.pvalue        0.000000
# Elle13.pvalue                  0.000000
# Elle13.fdr                     0.000000
# Elle13.lasso.prob              0.000000
# Weis16.csa.MW.pvalue           0.000000
# Sabb17.THP1                    0.000000
# Sabb17.TF1                     0.000000
# Sabb17.SKM1                    0.000000
# Sabb17.PL21                    0.000000
# Sabb17.P31.FUJ                 0.000000
# Sabb17.OCI.AML5                0.000000
# Sabb17.OCI.AML3                0.000000
# Sabb17.OCI.AML2                0.000000
# Weis16.csi.MW.pvalue           0.000000
# Sabb17.NB4.rep2                0.000000
# Sabb17.NB4.rep1                0.000000
# Sabb17.MonoMac1                0.000000
# Sabb17.MOLM13                  0.000000
# Weis16.csi.avg                 0.000000
# dtype: float64

# %% [markdown]
# For the genes above, the k-NN method might not be very accurate.
