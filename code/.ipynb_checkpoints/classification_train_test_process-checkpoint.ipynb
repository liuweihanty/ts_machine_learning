# %% [markdown]
# # Classification Train-test data processing

# %%
# Author: Shirley Zhou

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exclude non-coding gene from dataset

# %% [markdown]
# __Since `biomaRt` does not function well, the lists of protein-coding gene in train and test set are obtained from Weihan

# %%
chr7 = pd.read_csv("../data/Chr7_master_list.csv").drop(['Unnamed: 0'], axis = 1)
gwide = pd.read_csv("../data/Genomewide_master_list.csv")

# %%
gwide.head()
# Out:
#      Gene  GeneID                     Aliases  \
# 0  IGDCC3    9543              HsT18880, PUNC
# 1  HSF2BP   11077                         NaN
# 2  ADGRA2   25960                GPR124, TEM5
# 3    TKFC   26007                  DAK, NET45
# 4  ERMARD   55780  C6orf70, PVNH6, dJ266L20.3
#
#                                          description  \
# 0   immunoglobulin superfamily DCC subclass member 3
# 1  heat shock transcription factor 2 binding protein
# 2             adhesion G protein-coupled receptor A2
# 3                         triokinase and FMN cyclase
# 4             ER membrane associated RNA degradation
#
#                                   other_designations chromosome  HSC.logCPM  \
# 0  ; immunoglobulin superfamily DCC subclass memb...         15         NaN
# 1              ; heat shock factor 2-binding protein         21         NaN
# 2  ; adhesion G protein-coupled receptor A2|G-pro...          8         NaN
# 3  ; triokinase/FMN cyclase|ATP-dependent dihydro...         11         NaN
# 4  ; endoplasmic reticulum membrane-associated RN...          6         NaN
#
#    Brummelkamp.hap1.GTS.ratio  Brummelkamp.hap1.GTS.threshold  \
# 0                    0.503403                               0
# 1                    0.514247                               0
# 2                         NaN                               0
# 3                         NaN                               0
# 4                         NaN                               0
#
#    Brummelkamp.kbm7.GTS.ratio  ...  Sabbatini2017.THP.1  \
# 0                    0.534752  ...               -0.130
# 1                    0.521775  ...               -0.221
# 2                         NaN  ...                  NaN
# 3                         NaN  ...                  NaN
# 4                         NaN  ...               -0.070
#
#    Sabbatini2017.THP.1.threshold  Wallace2016.DEseq2.Log2.Fold.Change  \
# 0                              0                                  NaN
# 1                              0                                  NaN
# 2                              0                                  NaN
# 3                              0                                  NaN
# 4                              0                                  NaN
#
#    Wallace2016.DEseq2.P.Value  Wallace2016.threshold  \
# 0                         NaN                      0
# 1                         NaN                      0
# 2                         NaN                      0
# 3                         NaN                      0
# 4                         NaN                      0
#
#    Rep1_2.Mann.Whitney.p.value average.phenotype.of.strongest.3.2  \
# 0                 2.320000e-07                          -0.211542
# 1                 4.682615e-02                          -0.006646
# 2                          NaN                                NaN
# 3                          NaN                                NaN
# 4                 4.053098e-01                           0.010147
#
#    Unnamed: 83  Rep1_2.Mann.Whitney.p.value.1  \
# 0            1                       0.692807
# 1            1                       0.789091
# 2            0                            NaN
# 3            0                            NaN
# 4            0                       0.462927
#
#    average.phenotype.of.strongest.3.2.1
# 0                              0.004401
# 1                             -0.007323
# 2                                   NaN
# 3                                   NaN
# 4                             -0.012278
#
# [5 rows x 86 columns]
